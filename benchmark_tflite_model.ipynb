# %% [markdown]
# ### Quantized model benchmarking

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys 
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix

# %%
# configuration parameters 
TEST_DATA_DIR = '/Users/sanchit/Documents/Projects/Datasets/animals/test/'
MODEL_PATH = "./models/mobilenet.h5"
TFLITE_MODEL_DIR = "./models/tflite/"
QUANT_TYPE = "both_int8" # no_quant, w_int8, w_fp16, both_int8, both_fp16
TEST_SAMPLES = 450
NUM_CLASSES = 3
IMG_WIDTH, IMG_HEIGHT = 224, 224
BATCH_SIZE = 64
LABELS = ["cats", "dogs", "panda"]
QUANT_NAME_MAP = {"no_quant": "no quantization", "w_int8": "weights 8-bit INT quantized", 
                  "w_fp16": "weights 16-bit FP quantized", "both_int8": "both weights and activations INT8 quantized", 
                 "both_fp16": "both weights and activations FP-16 quantized"}

# %% [markdown]
# ### Load quantized model according to the type

# %%
if QUANT_TYPE == "no_quant":
    # model without any quantization
    print(f"interpreter for {QUANT_NAME_MAP[QUANT_TYPE]} loading ...")
    interpret = tf.lite.Interpreter(model_path = TFLITE_MODEL_DIR + "mobilenet_no_quant.tflite")
    interpret.allocate_tensors() # allocate memory to the model
    
elif QUANT_TYPE == "w_int8":
    # model with weights INT8 quantization
    print(f"interpreter for {QUANT_NAME_MAP[QUANT_TYPE]} loading ...")
    interpret = tf.lite.Interpreter(model_path = TFLITE_MODEL_DIR + "mobilenet_weights_int8_quant.tflite")
    interpret.allocate_tensors() # allocate memory to the model
    
elif QUANT_TYPE == "w_fp16":
    # model with weights FP16 quantization 
    print(f"interpreter for {QUANT_NAME_MAP[QUANT_TYPE]} loading ...")
    interpret = tf.lite.Interpreter(model_path = TFLITE_MODEL_DIR + "mobilenet_weights_float16_quant.tflite")
    interpret.allocate_tensors() # allocate memory to the model
    
elif QUANT_TYPE == "both_int8":
    # model with both weights and activations INT8 quantization 
    print(f"interpreter for {QUANT_NAME_MAP[QUANT_TYPE]} loading ...")
    interpret = tf.lite.Interpreter(model_path = TFLITE_MODEL_DIR + "mobilenet_both_int8_quant.tflite")
    interpret.allocate_tensors() # allocate memory to the model
    
elif QUANT_TYPE == "both_fp16":
    # model with both weights and activations INT8 quantization 
    print(f"interpreter for {QUANT_NAME_MAP[QUANT_TYPE]} loading ...")
    interpret = tf.lite.Interpreter(model_path = TFLITE_MODEL_DIR + "mobilenet_both_fp16_quant.tflite")
    interpret.allocate_tensors() # allocate memory to the model

else:
    print(f"Wrong quantization type has been chosen for {QUANT_NAME_MAP[QUANT_TYPE]}")
    sys.exit(0)
# Out:
# interpreter for both weights and activations INT8 quantized loading ...

# %%
# get indices of input and output tensors for each model 
input_ind = interpret.get_input_details()[0]["index"]
out_ind   = interpret.get_output_details()[0]["index"]

#input_ind_w_int8 = interpret_weights_int8.get_input_details()[0]["index"]
#out_ind_w_int8   = interpret_weights_int8.get_output_details()[0]["index"]

#input_ind_w_fp16 = interpret_weights_fp16.get_input_details()[0]["index"]
#out_ind_w_fp16   = interpret_weights_fp16.get_output_details()[0]["index"]

# %% [markdown]
# ### Create test generator

# %%
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_datagen.flow_from_directory(
    TEST_DATA_DIR,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=1,
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 450 images belonging to 3 classes.

# %% [markdown]
# References for using interpreter:
# - (check evaluate the models): https://www.tensorflow.org/lite/performance/post_training_float16_quant
# - it uses batch generator and batch predictions (TODO later): https://thinkmobile.dev/testing-tensorflow-lite-image-classification-model/
# - TinyML book chapter on Interpreter

# %%
# save the predicted class label (highest probability one) in a list
print(f"computing results for {QUANT_NAME_MAP[QUANT_TYPE]} ... \n")
results = []
accuracy_count = 0
for i in range(TEST_SAMPLES): 
    
    print(f"computing results for {i}th image ...")
    
    # generate a batch of images 
    test_image = test_generator.next() 
    
    # set the input image to the input index 
    interpret.set_tensor(input_ind, test_image[0]) 
    
    # run the inference 
    interpret.invoke() 
    
    # read the predictions from the output tensor
    predictions = interpret.tensor(out_ind) # or, get_tensor(out_ind)
    
    # get the highest predicted class
    pred_class = np.argmax(predictions()[0])
    
    #print("predicted class: ", pred_class, " and actual class: ", test_generator.classes[i])
    
    results.append(pred_class)
    
    if pred_class == test_generator.classes[i]:
        accuracy_count += 1
# Out:
# computing results for both weights and activations INT8 quantized ...
#
# computing results for 0th image ...
# computing results for 1th image ...
# computing results for 2th image ...
# computing results for 3th image ...
# computing results for 4th image ...
# computing results for 5th image ...
# computing results for 6th image ...
# computing results for 7th image ...
# computing results for 8th image ...
# computing results for 9th image ...
# computing results for 10th image ...
# computing results for 11th image ...
# computing results for 12th image ...
# computing results for 13th image ...
# computing results for 14th image ...
# computing results for 15th image ...
# computing results for 16th image ...
# computing results for 17th image ...
# computing results for 18th image ...
# computing results for 19th image ...
# computing results for 20th image ...
# computing results for 21th image ...
# computing results for 22th image ...
# computing results for 23th image ...
# computing results for 24th image ...
# computing results for 25th image ...
# computing results for 26th image ...
# computing results for 27th image ...
# computing results for 28th image ...
# computing results for 29th image ...
# computing results for 30th image ...
# computing results for 31th image ...
# computing results for 32th image ...
# computing results for 33th image ...
# computing results for 34th image ...
# computing results for 35th image ...
# computing results for 36th image ...
# computing results for 37th image ...
# computing results for 38th image ...
# computing results for 39th image ...
# computing results for 40th image ...
# computing results for 41th image ...
# computing results for 42th image ...
# computing results for 43th image ...
# computing results for 44th image ...
# computing results for 45th image ...
# computing results for 46th image ...
# computing results for 47th image ...
# computing results for 48th image ...
# computing results for 49th image ...
# computing results for 50th image ...
# computing results for 51th image ...
# computing results for 52th image ...
# computing results for 53th image ...
# computing results for 54th image ...
# computing results for 55th image ...
# computing results for 56th image ...
# computing results for 57th image ...
# computing results for 58th image ...
# computing results for 59th image ...
# computing results for 60th image ...
# computing results for 61th image ...
# computing results for 62th image ...
# computing results for 63th image ...
# computing results for 64th image ...
# computing results for 65th image ...
# computing results for 66th image ...
# computing results for 67th image ...
# computing results for 68th image ...
# computing results for 69th image ...
# computing results for 70th image ...
# computing results for 71th image ...
# computing results for 72th image ...
# computing results for 73th image ...
# computing results for 74th image ...
# computing results for 75th image ...
# computing results for 76th image ...
# computing results for 77th image ...
# computing results for 78th image ...
# computing results for 79th image ...
# computing results for 80th image ...
# computing results for 81th image ...
# computing results for 82th image ...
# computing results for 83th image ...
# computing results for 84th image ...
# computing results for 85th image ...
# computing results for 86th image ...
# computing results for 87th image ...
# computing results for 88th image ...
# computing results for 89th image ...
# computing results for 90th image ...
# computing results for 91th image ...
# computing results for 92th image ...
# computing results for 93th image ...
# computing results for 94th image ...
# computing results for 95th image ...
# computing results for 96th image ...
# computing results for 97th image ...
# computing results for 98th image ...
# computing results for 99th image ...
# computing results for 100th image ...
# computing results for 101th image ...
# computing results for 102th image ...
# computing results for 103th image ...
# computing results for 104th image ...
# computing results for 105th image ...
# computing results for 106th image ...
# computing results for 107th image ...
# computing results for 108th image ...
# computing results for 109th image ...
# computing results for 110th image ...
# computing results for 111th image ...
# computing results for 112th image ...
# computing results for 113th image ...
# computing results for 114th image ...
# computing results for 115th image ...
# computing results for 116th image ...
# computing results for 117th image ...
# computing results for 118th image ...
# computing results for 119th image ...
# computing results for 120th image ...
# computing results for 121th image ...
# computing results for 122th image ...
# computing results for 123th image ...
# computing results for 124th image ...
# computing results for 125th image ...
# computing results for 126th image ...
# computing results for 127th image ...
# computing results for 128th image ...
# computing results for 129th image ...
# computing results for 130th image ...
# computing results for 131th image ...
# computing results for 132th image ...
# computing results for 133th image ...
# computing results for 134th image ...
# computing results for 135th image ...
# computing results for 136th image ...
# computing results for 137th image ...
# computing results for 138th image ...
# computing results for 139th image ...
# computing results for 140th image ...
# computing results for 141th image ...
# computing results for 142th image ...
# computing results for 143th image ...
# computing results for 144th image ...
# computing results for 145th image ...
# computing results for 146th image ...
# computing results for 147th image ...
# computing results for 148th image ...
# computing results for 149th image ...
# computing results for 150th image ...
# computing results for 151th image ...
# computing results for 152th image ...
# computing results for 153th image ...
# computing results for 154th image ...
# computing results for 155th image ...
# computing results for 156th image ...
# computing results for 157th image ...
# computing results for 158th image ...
# computing results for 159th image ...
# computing results for 160th image ...
# computing results for 161th image ...
# computing results for 162th image ...
# computing results for 163th image ...
# computing results for 164th image ...
# computing results for 165th image ...
# computing results for 166th image ...
# computing results for 167th image ...
# computing results for 168th image ...
# computing results for 169th image ...
# computing results for 170th image ...
# computing results for 171th image ...
# computing results for 172th image ...
# computing results for 173th image ...
# computing results for 174th image ...
# computing results for 175th image ...
# computing results for 176th image ...
# computing results for 177th image ...
# computing results for 178th image ...
# computing results for 179th image ...
# computing results for 180th image ...
# computing results for 181th image ...
# computing results for 182th image ...
# computing results for 183th image ...
# computing results for 184th image ...
# computing results for 185th image ...
# computing results for 186th image ...
# computing results for 187th image ...
# computing results for 188th image ...
# computing results for 189th image ...
# computing results for 190th image ...
# computing results for 191th image ...
# computing results for 192th image ...
# computing results for 193th image ...
# computing results for 194th image ...
# computing results for 195th image ...
# computing results for 196th image ...
# computing results for 197th image ...
# computing results for 198th image ...
# computing results for 199th image ...
# computing results for 200th image ...
# computing results for 201th image ...
# computing results for 202th image ...
# computing results for 203th image ...
# computing results for 204th image ...
# computing results for 205th image ...
# computing results for 206th image ...
# computing results for 207th image ...
# computing results for 208th image ...
# computing results for 209th image ...
# computing results for 210th image ...
# computing results for 211th image ...
# computing results for 212th image ...
# computing results for 213th image ...
# computing results for 214th image ...
# computing results for 215th image ...
# computing results for 216th image ...
# computing results for 217th image ...
# computing results for 218th image ...
# computing results for 219th image ...
# computing results for 220th image ...
# computing results for 221th image ...
# computing results for 222th image ...
# computing results for 223th image ...
# computing results for 224th image ...
# computing results for 225th image ...
# computing results for 226th image ...
# computing results for 227th image ...
# computing results for 228th image ...
# computing results for 229th image ...
# computing results for 230th image ...
# computing results for 231th image ...
# computing results for 232th image ...
# computing results for 233th image ...
# computing results for 234th image ...
# computing results for 235th image ...
# computing results for 236th image ...
# computing results for 237th image ...
# computing results for 238th image ...
# computing results for 239th image ...
# computing results for 240th image ...
# computing results for 241th image ...
# computing results for 242th image ...
# computing results for 243th image ...
# computing results for 244th image ...
# computing results for 245th image ...
# computing results for 246th image ...
# computing results for 247th image ...
# computing results for 248th image ...
# computing results for 249th image ...
# computing results for 250th image ...
# computing results for 251th image ...
# computing results for 252th image ...
# computing results for 253th image ...
# computing results for 254th image ...
# computing results for 255th image ...
# computing results for 256th image ...
# computing results for 257th image ...
# computing results for 258th image ...
# computing results for 259th image ...
# computing results for 260th image ...
# computing results for 261th image ...
# computing results for 262th image ...
# computing results for 263th image ...
# computing results for 264th image ...
# computing results for 265th image ...
# computing results for 266th image ...
# computing results for 267th image ...
# computing results for 268th image ...
# computing results for 269th image ...
# computing results for 270th image ...
# computing results for 271th image ...
# computing results for 272th image ...
# computing results for 273th image ...
# computing results for 274th image ...
# computing results for 275th image ...
# computing results for 276th image ...
# computing results for 277th image ...
# computing results for 278th image ...
# computing results for 279th image ...
# computing results for 280th image ...
# computing results for 281th image ...
# computing results for 282th image ...
# computing results for 283th image ...
# computing results for 284th image ...
# computing results for 285th image ...
# computing results for 286th image ...
# computing results for 287th image ...
# computing results for 288th image ...
# computing results for 289th image ...
# computing results for 290th image ...
# computing results for 291th image ...
# computing results for 292th image ...
# computing results for 293th image ...
# computing results for 294th image ...
# computing results for 295th image ...
# computing results for 296th image ...
# computing results for 297th image ...
# computing results for 298th image ...
# computing results for 299th image ...
# computing results for 300th image ...
# computing results for 301th image ...
# computing results for 302th image ...
# computing results for 303th image ...
# computing results for 304th image ...
# computing results for 305th image ...
# computing results for 306th image ...
# computing results for 307th image ...
# computing results for 308th image ...
# computing results for 309th image ...
# computing results for 310th image ...
# computing results for 311th image ...
# computing results for 312th image ...
# computing results for 313th image ...
# computing results for 314th image ...
# computing results for 315th image ...
# computing results for 316th image ...
# computing results for 317th image ...
# computing results for 318th image ...
# computing results for 319th image ...
# computing results for 320th image ...
# computing results for 321th image ...
# computing results for 322th image ...
# computing results for 323th image ...
# computing results for 324th image ...
# computing results for 325th image ...
# computing results for 326th image ...
# computing results for 327th image ...
# computing results for 328th image ...
# computing results for 329th image ...
# computing results for 330th image ...
# computing results for 331th image ...
# computing results for 332th image ...
# computing results for 333th image ...
# computing results for 334th image ...
# computing results for 335th image ...
# computing results for 336th image ...
# computing results for 337th image ...
# computing results for 338th image ...
# computing results for 339th image ...
# computing results for 340th image ...
# computing results for 341th image ...
# computing results for 342th image ...
# computing results for 343th image ...
# computing results for 344th image ...
# computing results for 345th image ...
# computing results for 346th image ...
# computing results for 347th image ...
# computing results for 348th image ...
# computing results for 349th image ...
# computing results for 350th image ...
# computing results for 351th image ...
# computing results for 352th image ...
# computing results for 353th image ...
# computing results for 354th image ...
# computing results for 355th image ...
# computing results for 356th image ...
# computing results for 357th image ...
# computing results for 358th image ...
# computing results for 359th image ...
# computing results for 360th image ...
# computing results for 361th image ...
# computing results for 362th image ...
# computing results for 363th image ...
# computing results for 364th image ...
# computing results for 365th image ...
# computing results for 366th image ...
# computing results for 367th image ...
# computing results for 368th image ...
# computing results for 369th image ...
# computing results for 370th image ...
# computing results for 371th image ...
# computing results for 372th image ...
# computing results for 373th image ...
# computing results for 374th image ...
# computing results for 375th image ...
# computing results for 376th image ...
# computing results for 377th image ...
# computing results for 378th image ...
# computing results for 379th image ...
# computing results for 380th image ...
# computing results for 381th image ...
# computing results for 382th image ...
# computing results for 383th image ...
# computing results for 384th image ...
# computing results for 385th image ...
# computing results for 386th image ...
# computing results for 387th image ...
# computing results for 388th image ...
# computing results for 389th image ...
# computing results for 390th image ...
# computing results for 391th image ...
# computing results for 392th image ...
# computing results for 393th image ...
# computing results for 394th image ...
# computing results for 395th image ...
# computing results for 396th image ...
# computing results for 397th image ...
# computing results for 398th image ...
# computing results for 399th image ...
# computing results for 400th image ...
# computing results for 401th image ...
# computing results for 402th image ...
# computing results for 403th image ...
# computing results for 404th image ...
# computing results for 405th image ...
# computing results for 406th image ...
# computing results for 407th image ...
# computing results for 408th image ...
# computing results for 409th image ...
# computing results for 410th image ...
# computing results for 411th image ...
# computing results for 412th image ...
# computing results for 413th image ...
# computing results for 414th image ...
# computing results for 415th image ...
# computing results for 416th image ...
# computing results for 417th image ...
# computing results for 418th image ...
# computing results for 419th image ...
# computing results for 420th image ...
# computing results for 421th image ...
# computing results for 422th image ...
# computing results for 423th image ...
# computing results for 424th image ...
# computing results for 425th image ...
# computing results for 426th image ...
# computing results for 427th image ...
# computing results for 428th image ...
# computing results for 429th image ...
# computing results for 430th image ...
# computing results for 431th image ...
# computing results for 432th image ...
# computing results for 433th image ...
# computing results for 434th image ...
# computing results for 435th image ...
# computing results for 436th image ...
# computing results for 437th image ...
# computing results for 438th image ...
# computing results for 439th image ...
# computing results for 440th image ...
# computing results for 441th image ...
# computing results for 442th image ...
# computing results for 443th image ...
# computing results for 444th image ...
# computing results for 445th image ...
# computing results for 446th image ...
# computing results for 447th image ...
# computing results for 448th image ...
# computing results for 449th image ...

# %%
# compute the accuracy percentage
print(f"accuracy percentage for {QUANT_NAME_MAP[QUANT_TYPE]}: {round((accuracy_count / TEST_SAMPLES) * 100, 3)}% \n")
# Out:
# accuracy percentage for both weights and activations INT8 quantized: 97.556%

# %%
# Plot confusion matrix, classification report
print("-"*50)
print(f"Confusion matrix for {QUANT_NAME_MAP[QUANT_TYPE]}: \n")
print(confusion_matrix(y_true=test_generator.classes, y_pred=results))
print("-"*50)
print(f"Classification report for {QUANT_NAME_MAP[QUANT_TYPE]}: \n")
print(classification_report(y_true=test_generator.classes, y_pred=results, target_names=LABELS))
print("-"*50)
# Out:
# --------------------------------------------------
# Confusion matrix for both weights and activations INT8 quantized:
#
# [[147   3   0]
#  [  8 142   0]
#  [  0   0 150]]
# --------------------------------------------------
# Classification report for both weights and activations INT8 quantized:
#
#               precision    recall  f1-score   support
#
#         cats       0.95      0.98      0.96       150
#         dogs       0.98      0.95      0.96       150
#        panda       1.00      1.00      1.00       150
#
#     accuracy                           0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450
#
# --------------------------------------------------
